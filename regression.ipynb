# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# Show the first five rows of the data set.

# %%
df = pd.read_csv('./train.csv')
# prices.head(5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       700 non-null    float64
#  1   y       699 non-null    float64
# dtypes: float64(2)
# memory usage: 11.1 KB

# %%
df.head()
# Out:
#       x          y
# 0  24.0  21.549452
# 1  50.0  47.464463
# 2  15.0  17.218656
# 3  38.0  36.586398
# 4  87.0  87.288984

# %%
df.describe()
# Out:
#                  x           y
# count   700.000000  699.000000
# mean     54.985939   49.939869
# std     134.681703   29.109217
# min       0.000000   -3.839981
# 25%      25.000000   24.929968
# 50%      49.000000   48.973020
# 75%      75.000000   74.929911
# max    3530.157369  108.871618

# %%
x=df['x'].values
x
# Out:
# array([2.40000000e+01, 5.00000000e+01, 1.50000000e+01, 3.80000000e+01,
#        8.70000000e+01, 3.60000000e+01, 1.20000000e+01, 8.10000000e+01,
#        2.50000000e+01, 5.00000000e+00, 1.60000000e+01, 1.60000000e+01,
#        2.40000000e+01, 3.90000000e+01, 5.40000000e+01, 6.00000000e+01,
#        2.60000000e+01, 7.30000000e+01, 2.90000000e+01, 3.10000000e+01,
#        6.80000000e+01, 8.70000000e+01, 5.80000000e+01, 5.40000000e+01,
#        8.40000000e+01, 5.80000000e+01, 4.90000000e+01, 2.00000000e+01,
#        9.00000000e+01, 4.80000000e+01, 4.00000000e+00, 2.50000000e+01,
#        4.20000000e+01, 0.00000000e+00, 6.00000000e+01, 9.30000000e+01,
#        3.90000000e+01, 7.00000000e+00, 2.10000000e+01, 6.80000000e+01,
#        8.40000000e+01, 0.00000000e+00, 5.80000000e+01, 1.90000000e+01,
#        3.60000000e+01, 1.90000000e+01, 5.90000000e+01, 5.10000000e+01,
#        1.90000000e+01, 3.30000000e+01, 8.50000000e+01, 4.40000000e+01,
# ...

# %%
y=df['y'].values
y
# Out:
# array([ 21.54945196,  47.46446305,  17.21865634,  36.58639803,
#         87.28898389,  32.46387493,  10.78089683,  80.7633986 ,
#         24.61215147,   6.96331907,  11.23757338,  13.53290206,
#         24.60323899,  39.40049976,  48.43753838,  61.69900319,
#         26.92832418,  70.4052055 ,  29.34092408,  25.30895192,
#         69.02934339,  84.99484703,  57.04310305,  50.5921991 ,
#         83.02772202,  57.05752706,  47.95883341,  24.34226432,
#         94.68488281,  48.03970696,   7.08132338,  21.99239907,
#         42.33151664,   0.32908944,  61.92303698,  91.17716423,
#         39.45358014,   5.99606961,  22.59015942,  61.18044414,
#         85.02778957,  -1.28631089,  61.94273962,  21.96033347,
#         33.66194193,  17.60946242,  58.5630564 ,  52.82390762,
#         22.1363481 ,  35.07467353,  86.18822311,  42.63227697,
#          4.09817744,  61.2229864 ,  17.70677576,  11.85312574,
#         80.23051695,  62.64931741,   9.6168598 ,  20.02797699,
# ...

# %%
x=x.reshape(-1,1)
x
# Out:
# array([[2.40000000e+01],
#        [5.00000000e+01],
#        [1.50000000e+01],
#        [3.80000000e+01],
#        [8.70000000e+01],
#        [3.60000000e+01],
#        [1.20000000e+01],
#        [8.10000000e+01],
#        [2.50000000e+01],
#        [5.00000000e+00],
#        [1.60000000e+01],
#        [1.60000000e+01],
#        [2.40000000e+01],
#        [3.90000000e+01],
#        [5.40000000e+01],
#        [6.00000000e+01],
#        [2.60000000e+01],
#        [7.30000000e+01],
#        [2.90000000e+01],
#        [3.10000000e+01],
#        [6.80000000e+01],
#        [8.70000000e+01],
#        [5.80000000e+01],
#        [5.40000000e+01],
#        [8.40000000e+01],
#        [5.80000000e+01],
#        [4.90000000e+01],
#        [2.00000000e+01],
#        [9.00000000e+01],
#        [4.80000000e+01],
#        [4.00000000e+00],
#        [2.50000000e+01],
#        [4.20000000e+01],
#        [0.00000000e+00],
#        [6.00000000e+01],
#        [9.30000000e+01],
#        [3.90000000e+01],
# ...

# %%
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size=0.25, random_state =4)

# %% [markdown]
# Ensure that any date columns have been cast into a datetime object in your DataFrame
# Using a regression model, split your data into train and test data.

# %%
model = LinearRegression()

# %% [markdown]
# Fit your training split to the regression model

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Show your regression model’s score.

# %%
score=model.score(x_train, y_train)
score
# Out:
# 0.9908866139270751

# %% [markdown]
# Draw at least three conclusions from your regression model.

# %%
x_y = model.predict(x_test)
x_y
# Out:
# array([ 8.28277042e+01, -1.32642101e-01,  4.86496912e+00,  9.48219711e+01,
#         5.68401258e+01,  4.88439479e+01,  8.48267487e+01,  7.48315263e+01,
#         5.78396481e+01,  4.08477699e+01,  6.28372593e+01,  7.68305707e+01,
#         8.66880144e-01,  3.98482477e+01,  3.18520697e+01,  3.18520697e+01,
#         7.38320040e+01,  3.48506365e+01,  6.86401361e+00,  5.48410814e+01,
#         2.48554140e+01,  2.86592463e+00,  4.18472922e+01,  2.38558918e+01,
#         8.88248377e+01,  6.88343928e+01,  4.18472922e+01,  9.18234044e+01,
#         8.08286597e+01,  9.78205379e+01,  3.68496810e+01,  9.48219711e+01,
#         9.38224489e+01,  5.78396481e+01,  3.48506365e+01,  8.88248377e+01,
#         8.66880144e-01,  4.18472922e+01,  3.86544688e+00,  2.38558918e+01,
#        -1.32642101e-01, -1.32642101e-01,  5.88391703e+01,  4.78444256e+01,
#         2.08573250e+01,  8.58262709e+01,  5.08429924e+01,  6.86401361e+00,
# ...

# %%
linear_model = LinearRegression()
linear_model.fit(x_train.reshape(-1, 1), y_train.reshape(-1, 1))
plt.plot(x_train,y_train)

# %%
plt.scatter(x_test, y_test)
plt.plot(x_test, x_y , color = 'gray')
plt.xlabel('Iterating Values')
plt.ylabel('equation')
plt.show()

# %%
plt.scatter(x_train, y_train, color='green')
plt.scatter(x_test, y_test, color='blue')
plt.plot(x_test, y_test, color='red')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.show()

# %% [markdown]
# Conclusions:
#
# The x-values are numbers between 0 and 100. The corresponding y-values have been generated using the Excel function NORMINV(RAND(), x, 3). Consequently, the best estimate for y should be x.
